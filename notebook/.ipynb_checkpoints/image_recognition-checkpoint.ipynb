# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../data/1*KvQ_ceyq0DRFiSkyy4lTwA.png')
plt.imshow(img)
plt.show()

# %%
##Textread example
img = cv2.imread('../data/1*KvQ_ceyq0DRFiSkyy4lTwA.png')
text = pytesseract.image_to_string(img)
print(text)
# Out:
# ((( BREAKING NEWS )))

# %%
##Tft ex
img = cv2.imread('../data/maxresdefault.jpg')
plt.imshow(img)
plt.show()

# %%
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Oecd
# Care Evy

# %%
##Tft ex
img = cv2.imread('../data/shop_12 (copy).png')
plt.imshow(img)
plt.show()
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Erect
# Chao)
# rod at

# %%
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Erect
# Chao)
# rod at

# %%
##Tft ex
img = cv2.imread('../data/shop_12 (copy).png')
plt.imshow(img)
plt.show()
